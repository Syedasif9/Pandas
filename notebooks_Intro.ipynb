# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
#crete dataframe
df=pd.DataFrame([11,22,33,44,55],columns=['A'])
df
# Out:
#     A
# 0  11
# 1  22
# 2  33
# 3  44
# 4  55

# %% [raw]
# #use shift + tab to check all the function information.

# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data={
    'Name':['Syed','Asif','Altaf'],
    'age':[25,26,27],
    'salary':[20000,30000,40000]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#     Name  age  salary
# 0   Syed   25   20000
# 1   Asif   26   30000
# 2  Altaf   27   40000

# %%
df.head(1) returns top rows
# Out:
#    Name  age  salary
# 0  Syed   25   20000

# %%
df.tail(1) returns bottom rows
# Out:
#     Name  age  salary
# 2  Altaf   27   40000

# %%
df.shape #retruns rowsxcolumns.
# Out:
# (3, 3)

# %%
df.columns #will list column name
# Out:
# Index(['Name', 'age', 'salary'], dtype='object')

# %%
df.rename(columns={'salary':'monthly salary'},inplace=True) #rename column name and inplace should be true to permanently change column name.
df
# Out:
#     Name  age  monthly salary
# 0   Syed   25           20000
# 1   Asif   26           30000
# 2  Altaf   27           40000

# %%
df.info() #provides dataframes information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            3 non-null      object
#  1   age             3 non-null      int64
#  2   monthly salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 132.0+ bytes

# %%
df.describe() #provides highlevel statistical summary
# Out:
#         age  monthly salary
# count   3.0             3.0
# mean   26.0         30000.0
# std     1.0         10000.0
# min    25.0         20000.0
# 25%    25.5         25000.0
# 50%    26.0         30000.0
# 75%    26.5         35000.0
# max    27.0         40000.0

# %%
df.to_csv("pdtestdata.csv",index=False) #export dataframe

# %%
pd.read_csv('pdtestdata.csv') #import dataframe
# Out:
#     Name  age  monthly salary
# 0   Syed   25           20000
# 1   Asif   26           30000
# 2  Altaf   27           40000

# %%
load_df=pd.read_csv('pdtestdata.csv')
load_df
# Out:
#     Name  age  monthly salary
# 0   Syed   25           20000
# 1   Asif   26           30000
# 2  Altaf   27           40000

# %%
df
# Out:
#     Name  age  monthly salary
# 0   Syed   25           20000
# 1   Asif   26           30000
# 2  Altaf   27           40000

# %%
#select required columns 
df[['Name','age']]
# Out:
#     Name  age
# 0   Syed   25
# 1   Asif   26
# 2  Altaf   27

# %%
df.loc[df.Name=='Syed'] #use df.loc to find row  level data
# Out:
#    Name  age  monthly salary
# 0  Syed   25           20000

# %%
df.loc[(df.Name=='Syed') & (df.age==25)] #perform comparision using df.loc
# Out:
#    Name  age  monthly salary
# 0  Syed   25           20000

# %%
df.iloc[0] #index based search on data
# Out:
# Name               Syed
# age                  25
# monthly salary    20000
# Name: 0, dtype: object

# %%
df.iloc[0:2]
# Out:
#    Name  age  monthly salary
# 0  Syed   25           20000
# 1  Asif   26           30000

# %%
df #filter dataframe
# Out:
#     Name  age  monthly salary
# 0   Syed   25           20000
# 1   Asif   26           30000
# 2  Altaf   27           40000

# %%
df['age']>25
# Out:
# 0    False
# 1     True
# 2     True
# Name: age, dtype: bool

# %%
df[df['age']>25]
# Out:
#     Name  age  monthly salary
# 1   Asif   26           30000
# 2  Altaf   27           40000

# %%
df_age_filter=df[df['age']>25]
df_age_filter
# Out:
#     Name  age  monthly salary
# 1   Asif   26           30000
# 2  Altaf   27           40000

# %%
df[(df['age']>25) & (df['monthly salary']>30000)]
# Out:
#     Name  age  monthly salary
# 2  Altaf   27           40000

# %%
df.where(df['age']>25)
# Out:
#     Name   age  monthly salary
# 0    NaN   NaN             NaN
# 1   Asif  26.0         30000.0
# 2  Altaf  27.0         40000.0

# %%
df.where(df['age']>25,other='not eligible')
# Out:
#            Name           age monthly salary
# 0  not eligible  not eligible   not eligible
# 1          Asif            26          30000
# 2         Altaf            27          40000

# %%
df #rows and column operations
# Out:
#     Name  age  monthly salary
# 0   Syed   25           20000
# 1   Asif   26           30000
# 2  Altaf   27           40000

# %%
#add new column
df['Team']=['HR','CEO','DE']
df
# Out:
#     Name  age  monthly salary Team
# 0   Syed   25           20000   HR
# 1   Asif   26           30000  CEO
# 2  Altaf   27           40000   DE

# %%
df['Bonus']= df['monthly salary'] * 0.10
df
# Out:
#     Name  age  monthly salary Team   Bonus
# 0   Syed   25           20000   HR  2000.0
# 1   Asif   26           30000  CEO  3000.0
# 2  Altaf   27           40000   DE  4000.0

# %%
len(df) #returns length of dataframe
# Out:
# 3

# %%
df.loc[len(df)]=['imran',24,10000,'analyst',1000]
df
# Out:
#     Name  age  monthly salary     Team   Bonus
# 0   Syed   25           20000       HR  2000.0
# 1   Asif   26           30000      CEO  3000.0
# 2  Altaf   27           40000       DE  4000.0
# 3  imran   24           10000  analyst  1000.0
# 4  imran   24           10000  analyst  1000.0
# 5  imran   24           10000  analyst  1000.0

# %%
# !pip install pandas
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 get_ipython().system('pip install pandas')
#
# File /lib/python3.13/site-packages/IPython/core/interactiveshell.py:2620, in InteractiveShell.system_piped(self, cmd)
#    2615     raise OSError("Background processes not supported.")
#    2617 # we explicitly do NOT return the subprocess status code, because
#    2618 # a non-None value would trigger :func:`sys.displayhook` calls.
#    2619 # Instead, we store the exit_code in user_ns.
# -> 2620 self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#
# File /lib/python3.13/site-packages/IPython/utils/_process_emscripten.py:10, in system(cmd)
#       9 def system(cmd):
# ---> 10     raise OSError("Not available")
#
# OSError: Not available

# %% [markdown]
# ## Next steps 🏃
#
# This is just a short introduction to JupyterLab and Jupyter Notebooks. See below for some more ways to interact with tools in the Jupyter ecosystem, and its community.
#
# ### Other notebooks in this demo
#
# Here are some other notebooks in this demo. Each of the items below corresponds to a file or folder in the **file browser to the left**.
#
# - [**`Lorenz.ipynb`**](Lorenz.ipynb) uses Python to demonstrate interactive visualizations and computations around the [Lorenz system](https://en.wikipedia.org/wiki/Lorenz_system). It shows off basic Python functionality, including more visualizations, data structures, and scientific computing libraries.
# - [**`r.ipynb`**](r.ipynb) demonstrates the R programming language for statistical computing and data analysis.
# - [**`cpp.ipynb`**](cpp.ipynb) demonstrates the C++ programming language for scientific computing and data analysis.
# - [**`sqlite.ipynb`**](sqlite.ipynb) demonstrates how an in-browser sqlite kernel to run your own SQL commands from the notebook. It uses the [jupyterlite/xeus-sqlite-kernel](https://github.com/jupyterlite/xeus-sqlite-kernel).
#
# ### Other sources of information in Jupyter
#
# - **More on using JupyterLab**: See [the JupyterLab documentation](https://jupyterlab.readthedocs.io/en/stable/) for more thorough information about how to install and use JupyterLab.
# - **More interactive demos**: See [try.jupyter.org](https://try.jupyter.org) for more interactive demos with the Jupyter ecosystem.
# - **Learn more about Jupyter**: See [the Jupyter community documentation](https://docs.jupyter.org) to learn more about the project, its community and tools, and how to get involved.
# - **Join our discussions**: The [Jupyter Community Forum](https://discourse.jupyter.org) is a place where many in the Jupyter community ask questions, help one another, and discuss issues around interactive computing and our ecosystem.

# %%
#update values
df.loc[4,'Name']='galib'
df
# Out:
#     Name  age  monthly salary     Team   Bonus
# 0   Syed   25           20000       HR  2000.0
# 1   Asif   26           30000      CEO  3000.0
# 2  Altaf   27           40000       DE  4000.0
# 3  imran   24           10000  analyst  1000.0
# 4  galib   24           10000  analyst  1000.0
# 5  imran   24           10000  analyst  1000.0

# %%
df.loc[5,'Name']='sharuk'
df
# Out:
#      Name  age  monthly salary     Team   Bonus
# 0    Syed   25           20000       HR  2000.0
# 1    Asif   26           30000      CEO  3000.0
# 2   Altaf   27           40000       DE  4000.0
# 3   imran   24           10000  analyst  1000.0
# 4   galib   24           10000  analyst  1000.0
# 5  sharuk   24           10000  analyst  1000.0

# %%
#delete values
df.drop(df[df.Name=='galib'].index)
# Out:
#      Name  age  monthly salary     Team   Bonus
# 0    Syed   25           20000       HR  2000.0
# 1    Asif   26           30000      CEO  3000.0
# 2   Altaf   27           40000       DE  4000.0
# 3   imran   24           10000  analyst  1000.0
# 5  sharuk   24           10000  analyst  1000.0

# %%
df.drop('Bonus',axis=1)
# Out:
#      Name  age  monthly salary     Team
# 0    Syed   25           20000       HR
# 1    Asif   26           30000      CEO
# 2   Altaf   27           40000       DE
# 3   imran   24           10000  analyst
# 4   galib   24           10000  analyst
# 5  sharuk   24           10000  analyst

# %%
df.drop(df[df.Name=='imran'].index) #drop rows
# Out:
#      Name  age  monthly salary     Team   Bonus
# 0    Syed   25           20000       HR  2000.0
# 1    Asif   26           30000      CEO  3000.0
# 2   Altaf   27           40000       DE  4000.0
# 4   galib   24           10000  analyst  1000.0
# 5  sharuk   24           10000  analyst  1000.0

# %%
df.drop('Bonus',axis=1,inplace=True) #drop columns

# %%
df
# Out:
#      Name  age  monthly salary     Team
# 0    Syed   25           20000       HR
# 1    Asif   26           30000      CEO
# 2   Altaf   27           40000       DE
# 3   imran   24           10000  analyst
# 4   galib   24           10000  analyst
# 5  sharuk   24           10000  analyst

# %%
df.loc[4,'Team']='instructor'

# %%
df
# Out:
#     name  age  salary team        doj  month
# 0   syed   25   20000   hr 2026-01-01      1
# 1   asif   26   30000   de 2026-02-02      2
# 2  altaf   27   40000  sde 2026-03-03      3
# 3  galib   24   10000  NaN 2026-04-04      4

# %%
df.loc[5,'Team']='field operator'

# %%
df
# Out:
#      Name  age  monthly salary            Team
# 0    Syed   25           20000              HR
# 1    Asif   26           30000             CEO
# 2   Altaf   27           40000              DE
# 3   imran   24           10000         analyst
# 4   galib   24           10000      instructor
# 5  sharuk   24           10000  field operator

# %%
df.drop(df[df.Name=='imran'].index,inplace=True)

# %%
df
# Out:
#      Name  age  monthly salary            Team
# 0    Syed   25           20000              HR
# 1    Asif   26           30000             CEO
# 2   Altaf   27           40000              DE
# 4   galib   24           10000      instructor
# 5  sharuk   24           10000  field operator

# %%
df.drop(5,inplace=True)

# %%
df
# Out:
#     Name  age  monthly salary        Team
# 0   Syed   25           20000          HR
# 1   Asif   26           30000         CEO
# 2  Altaf   27           40000          DE
# 4  galib   24           10000  instructor

# %%
df.rename(columns={'monthly salary':'salary'},inplace=True)

# %%
df
# Out:
#     Name  age  salary        Team
# 0   Syed   25   20000          HR
# 1   Asif   26   30000         CEO
# 2  Altaf   27   40000          DE
# 4  galib   24   10000  instructor

# %%
df.sort_values('age')
# Out:
#     Name  age  salary        Team
# 4  galib   24   10000  instructor
# 0   Syed   25   20000          HR
# 1   Asif   26   30000         CEO
# 2  Altaf   27   40000          DE

# %%
df.loc[4,'age']=28
df
# Out:
#     name   age   salary team        doj  month
# 0   syed  25.0  20000.0   hr 2026-01-01    1.0
# 1   asif  26.0  30000.0   de 2026-02-02    2.0
# 2  altaf  27.0  40000.0  sde 2026-03-03    3.0
# 3  galib  24.0  10000.0  NaN 2026-04-04    4.0
# 4    NaN  28.0      NaN  NaN        NaT    NaN

# %%
import pandas as pd
df=pd.DataFrame(['syed','asif','altaf','galib'], columns=['name'])
df
# Out:
#     name
# 0   syed
# 1   asif
# 2  altaf
# 3  galib

# %%
df['age']=[25,26,27,24]

# %%
df
# Out:
#     name  age
# 0   syed   25
# 1   asif   26
# 2  altaf   27
# 3  galib   24

# %%
df['salary']=[20000,30000,40000,10000]

# %%
df
# Out:
#     name  age  salary
# 0   syed   25   20000
# 1   asif   26   30000
# 2  altaf   27   40000
# 3  galib   24   10000

# %%
df['team']=['hr','de','sde','instructor']

# %%
df
# Out:
#     name  age  salary        team
# 0   syed   25   20000          hr
# 1   asif   26   30000          de
# 2  altaf   27   40000         sde
# 3  galib   24   10000  instructor

# %%
df['doj']=['2026-01-01','2026-02-02','2026-03-03','2026-04-04']

# %%
df
# Out:
#     name  age  salary        team         doj
# 0   syed   25   20000          hr  2026-01-01
# 1   asif   26   30000          de  2026-02-02
# 2  altaf   27   40000         sde  2026-03-03
# 3  galib   24   10000  instructor  2026-04-04

# %%
df['doj'].dtype
# Out:
# dtype('O')

# %%
 df['doj']=pd.to_datetime(df['doj']) #convert obj type into date

# %%
df
# Out:
#     name  age  salary        team        doj
# 0   syed   25   20000          hr 2026-01-01
# 1   asif   26   30000          de 2026-02-02
# 2  altaf   27   40000         sde 2026-03-03
# 3  galib   24   10000  instructor 2026-04-04

# %%
df['doj'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['month']=df['doj'].dt.month
df
# Out:
#     name  age  salary team        doj  month
# 0   syed   25   20000   hr 2026-01-01      1
# 1   asif   26   30000   de 2026-02-02      2
# 2  altaf   27   40000  sde 2026-03-03      3
# 3  galib   24   10000  NaN 2026-04-04      4

# %%
df['doj'].dt.year #date functions
df['doj'].dt.month
df['doj'].dt.day
df['doj'].dt.day_name()
# Out:
# 0    Thursday
# 1      Monday
# 2     Tuesday
# 3    Saturday
# Name: doj, dtype: object

# %%
df['doj']-pd.Timedelta(days=30)  #difference btw dates (+,-)
# Out:
# 0   2025-12-02
# 1   2026-01-03
# 2   2026-02-01
# 3   2026-03-05
# Name: doj, dtype: datetime64[ns]

# %%
#handling missing values

# %%
df.isnull() #returns true if value is null.
# Out:
#     name    age  salary   team    doj
# 0  False  False   False  False  False
# 1  False  False   False  False  False
# 2  False  False   False  False  False
# 3  False  False   False  False  False

# %%
df
# Out:
#     name  age  salary        team        doj
# 0   syed   25   20000          hr 2026-01-01
# 1   asif   26   30000          de 2026-02-02
# 2  altaf   27   40000         sde 2026-03-03
# 3  galib   24   10000  instructor 2026-04-04

# %%
import numpy as np
df.loc[df.name=='galib','team']=np.nan
df
# Out:
#     name  age  salary team        doj
# 0   syed   25   20000   hr 2026-01-01
# 1   asif   26   30000   de 2026-02-02
# 2  altaf   27   40000  sde 2026-03-03
# 3  galib   24   10000  NaN 2026-04-04

# %%
df.isnull()
# Out:
#     name    age  salary   team    doj
# 0  False  False   False  False  False
# 1  False  False   False  False  False
# 2  False  False   False  False  False
# 3  False  False   False   True  False

# %%
df.isnull().sum() #to check null values in large dataframes
# Out:
# name      0
# age       0
# salary    0
# team      1
# doj       0
# dtype: int64

# %%
df.fillna('bench')
# Out:
#     name  age  salary   team        doj
# 0   syed   25   20000     hr 2026-01-01
# 1   asif   26   30000     de 2026-02-02
# 2  altaf   27   40000    sde 2026-03-03
# 3  galib   24   10000  bench 2026-04-04

# %%
df['team'].value_counts()
# Out:
# team
# hr     1
# de     1
# sde    1
# Name: count, dtype: int64

# %%
df['doj'].dt.day_name.value_counts()
# Out:
# doj
# Thursday    1
# Monday      1
# Tuesday     1
# Saturday    1
# Name: count, dtype: int64

# %%
df.groupby('month')['salary'].mean()
# Out:
# month
# 1    20000.0
# 2    30000.0
# 3    40000.0
# 4    10000.0
# Name: salary, dtype: float64
